# %% [markdown]
# ## Introduction:
# The objective of this analysis is to identity strategic locations and install EV charging stations.
# My client for this project is Volta Inc. Volta Inc. is a market leader in EV charging industry, that provides first thirty minutes of charging free for all vehicles. Volta Inc. is a technology company, that aims to build over 200,000 supercharger stations until 2030 for all Electric vehicles in the United States.
# I've analyzed multiple Datasets for this project, namely Annual Average Daily Traffic, NYS EV charging stations, Sales Tax (Per Capita) per county and EV ownerships by county. I'll build a ranking model to narrow down on my shorlisted locations. I have used Data over the last five years for this project. (2016-2021)
# ## New York state has 62 counties.
# ![EV%20Ownership%20Map.PNG](attachment:EV%20Ownership%20Map.PNG)

# %%
from IPython.display import Image

PATH = "C:/Users/reyno/OneDrive/Desktop/Metis/"
Image(filename = PATH + "Bus_Fund-1.png", width=1000, height=1000)

# %% [markdown]
# ![Sales%20tax%20map-2.PNG](attachment:Sales%20tax%20map-2.PNG)

# %% [markdown]
# Model Ranking Criteria as per county:
# 1) More Sales Tax gets a lower rank, as it deincentivizes buyers to buy an Electric vehicle.
# 2) Higher Population Density gets a higher rank, as it increases the probability of EV charging station usage.
# 3) Higher Electric vehicles gets a higher rank as more potential customers.
# 4) Lower Number of EV charging stations gets a higher rank as there is more opportunity to install new stations.
# 5) Lower Electric vehicles per county gets a lower rank as it diminishes the potential usage of installed EV charging stations.
#
# Weighted Ranking:
# The weightage has been equally divided between Population Density, Sales Tax per Capita, EV ownership and EVs per station.
#
# The Final ranking of counties is as follows: ![Final_rank.PNG.PNG](attachment:Final_rank.PNG.PNG)
